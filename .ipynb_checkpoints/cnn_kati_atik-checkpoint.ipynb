# %%
#pip install imutils

# %%
#pip install opencv-python

# %%
#pip install tensorflow

# %%
#veriyi okuma ve işleme adımmında kullanılacak olan kütüphaneler
import cv2
import urllib
import itertools
import numpy as np
import pandas as pd
import seaborn as sns
import random, os, glob
from imutils import paths
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from urllib.request import urlopen

# %%
#warningleri kapatmak için kullanılmaktadır.
import warnings
warnings.filterwarnings('ignore')

# %%
#Model degerlendirme için kullanılacak olan kütüphaneler
from sklearn.metrics import confusion_matrix, classification_report

# %%
#Model için kullanılacak olan kütüphaneler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
from tensorflow.keras.layers import Conv2D, Flatten, MaxPooling2D,Dense,Dropout, SpatialDropout2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img, array_to_img

# %%
target_size=(224, 224),
waste_labels = {'cardboard' : 0 , 'glass': 1, 'metal': 2, 'paper': 3, 'plastic': 4, 'trash' : 5}

# %%
def load_datasets(path):
    """
    Görsellerin bulunduğu diizndeki görüntüyü okuyup etiketlerini oluşturur
    Parametreler:
    path: Görsellerim bulunduğu dizini ifade eder.
    Return:
    x: Görüntülere ait matris bilgilerini tutar.
    labels: Görüntünün ait olduğu sınıf bilgisini tutan liste
    """
    x = []
    labels = []

    # gönderdiğimiz pathdeki görüntüleri listleyip sıralamaktadır.
    image_paths = sorted(list(paths.list_images(path)))

    for image_path in image_paths:
        #belirtilen pathdeki görüntüler openCV kütüphanesi ile okunmaktadır.
        img = cv2.imread(image_path)

        #okunan görüntüler baslangıcta belirlenen target_size a göre yeniden ölceklendirebilir.
        img = cv2.resize(img,target_size)

        #ölceklendirilen görüntüler x listesine eklenir.
        x.append(img)

        #her bir path '/' ifadesi ile ayrıldıgında dönen listenin sondan ikinci elemanı labelı temsil etmektedir.
        label = image_path.split(os.path.sep)[-2]

        #yakalanan labelların sayısal deger karsılıklarının olduğu waste_labels sözlügü içerisinden 
        #gönderilen key degerine karsılık value degeri alınarak label olusuturulur.
        labels.append(waste_labels[label])

    #veri seti random bir sekilde karısıtırılır.
    x, labels = shuffle(x,labels,random_state=42)

    #boyut ve sınıf bilgisi raporlanmaktadır.
    print(f"X boyutu: {np.array(x).shape}")
    print(f"Label sınıf sayısı: {len(np.unique(labels))} Gözlem sayısı: {len(labels)}")

    return x, labels

# %%
dir_path = r"C:\Users\glylm\Desktop\dp\Solid_waste_detection_with_CNN\Garbage_classification\Garbageclassification"  # Veri kümesinin bulunduğu dizinin yolunu belirtin
target_size = (224,224)
x, labels = load_datasets(dir_path)
# Out:
# X boyutu: (5051, 224, 224, 3)
# Label sınıf sayısı: 6 Gözlem sayısı: 5051

# %%
#görüntü boyutlrının tutulması
input_shape = (np.array(x[0]).shape[1], np.array(x[0]).shape[1],3)
print(input_shape)
# Out:
# (224, 224, 3)

# %% [markdown]
# ### veri setindeki örnekler gösterilmesi

# %%
def visualize_img(image_batch, label_batch):
    """
    Veri seti içerisindeki görüntü görsellestiriilir
    paarametreler:
    image_batch: görüntülere ait matris bilgilerini tutuar.
    label_batch: görüntünün  ait olduğu sınıf bilgisini  tutan liste
    
    """
    plt.figure(figsize = (10,10))
    for n in range(10):

        ax = plt.subplot(5,5,n+1)
        plt.imshow(image_batch[n])
        plt.title(np.array(list(waste_labels.keys()))[to_categorical(labels, num_classes=6)[n]==1][0].title())
        plt.axis('off')

# %%
visualize_img(x,labels)

# %% [markdown]
# ### veriyi hazırlamak

# %%
# Train veri seti için bir generator tanımlıyoruz.
train = ImageDataGenerator(horizontal_flip= True, #görüntüleri rastgele yatay cevirir
                          vertical_flip= True, #rastgele dikey ceviriri
                           validation_split = 0.1, #test veri seti oranı
                           rescale = 1./255, # yeniden ölceklendirme
                           shear_range = 0.1, # görüntüye egim verir
                           zoom_range = 0.1, #genişlik kaydırma
                           width_shift_range = 0.1,
                           height_shift_range= 0.1
                          )
# Test veri seti için bir generator tanımlıyoruz
test = ImageDataGenerator(rescale = 1/255,
                          validation_split= 0.1)

# %%
#flow_from_directory = fonksiyonuyla tensorflow ortamında görüntüleri okumak için kullanıyoruz
train_generator = train.flow_from_directory(directory = dir_path, #görüntülerin bulundugu dizin bilgisi
                                      target_size = (target_size), #bulunan görüntüleri ölceklendirmekiçin
                                      batch_size=251, # veri gruplarının boyutunu
                                      class_mode ='categorical',
                                      subset ='training')

test_generator = test.flow_from_directory(directory = dir_path,
                                      target_size = (target_size),
                                      batch_size=251,
                                      class_mode ='categorical',
                                      subset ='validation')
# Out:
# Found 4548 images belonging to 6 classes.
# Found 503 images belonging to 6 classes.

# %% [markdown]
# ## Modelleme ( modeling)
# * sequential
# * Evrişim Katmanı(Convolution Layer,Conv2D)
# * Havuzlama Katmanı(Pooling Layer)
# * Aktivasyon Fonksiyonu Katmanı(Activation layer)
# * Flattening Katmanı
# * Dense katmanı
# * Dropout Katmanı

# %%
from tensorflow import keras
from tensorflow.keras.layers import Conv2D
# 1.katman  sequential sıralı katman
model = keras.Sequential()
# 2.katman evrisim katmanı(algılama kısmı
model.add(Conv2D(filters=32, # görüntü üzerindeki filtre sayısı
                 kernel_size=(3,3), #gezdirelecek olan filtre sayısı
                 padding = 'same', # evrisim katmanı sonraası pixel ekleme yapılarak giris vecıksı boyut farkı ortadan kaldırılır
                 input_shape = (input_shape), # giris bilgilerinin boyut bilgisini ifade etmektedir
                 activation ='relu')) # act fonksiyonumuz
# 3.katman pooling (havuzlama) ve 4.katman activasyon kısmı burada
model.add(MaxPooling2D( #sadece boyut azaltmak için kullanılır evrisim katmanından sonra
    pool_size = 2, #görüntü üzerinde gezdirilecek boyut bilgisi
     strides=(2,2)))
#2. ve 3.katman 3 kere
model.add(Conv2D(filters=64, # görüntü üzerindeki filtre sayısı
                 kernel_size=(3,3), #gezdirelecek olan filtre sayısı
                 padding = 'same', # evrisim katmanı sonraası pixel ekleme yapılarak giris vecıksı boyut farkı ortadan kaldırılır
                 input_shape = (input_shape), # giris bilgilerinin boyut bilgisini ifade etmektedir
                 activation ='relu')) # act fonksiyonumuz
# 3.katman pooling (havuzlama) ve 4.katman activasyon kısmı burada
model.add(MaxPooling2D( #sadece boyut azaltmak için kullanılır evrisim katmanından sonra
    pool_size = 2, #görüntü üzerinde gezdirilecek boyut bilgisi
     strides=(2,2)))
model.add(Conv2D(filters=32, # görüntü üzerindeki filtre sayısı
                 kernel_size=(3,3), #gezdirelecek olan filtre sayısı
                 padding = 'same', # evrisim katmanı sonraası pixel ekleme yapılarak giris vecıksı boyut farkı ortadan kaldırılır
                 input_shape = (input_shape), # giris bilgilerinin boyut bilgisini ifade etmektedir
                 activation ='relu')) # act fonksiyonumuz
model.add(MaxPooling2D( #sadece boyut azaltmak için kullanılır evrisim katmanından sonra
    pool_size = 2, #görüntü üzerinde gezdirilecek boyut bilgisi
     strides=(2,2)))
# 5.katman Flatenning katmanı(tek boyutlu diziye cevirir)
model.add(Flatten())
#6.katman(dense)(nöronları=units diğer katmana girdi olarak katar) ve 
#7.katman dropout(asırır ogrenmenin önüne gecmek için kullanılır)
model.add(Dense(units = 64, activation ='relu'))
model.add(Dropout(rate=0.2))
model.add(Dense(units=32,activation='relu'))
model.add(Dropout(rate=0.2))
model.add(Dense(units=6, activation='softmax')) # 6 sınıflı

# %%
#model özeti
model.summary()
#layer(type) = katmnaların isimleri
#output shape = cıktıların boyut bilgisi(32 filtre sayısı

#ögrenilecek olan parametre sayısı  896
#
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 56, 56, 32)     │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │     1,605,696 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 6)              │           198 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,645,830 (6.28 MB)
#  Trainable params: 1,645,830 (6.28 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Optimizasyon ve değerlendirme metriklerinin ayarlanması

# %%
model.compile(loss = 'categorical_crossentropy',
             # Modelin hata fonksiyonunu (loss function) çok sınıflı sınıflandırma için
              #categorical crossentropy olarak ayarlar.
              optimizer = 'adam',
    # Modelin optimizasyon algoritmasını adam olarak ayarlar.
              metrics= [tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), "acc"])
# Modelin performansını ölçmek için kesinlik (precision),
#geri çağırma (recall) ve doğruluk (accuracy) metriklerini kullanır.

# %%
callbacks = [EarlyStopping(monitor = 'val_loss', patience= 50, verbose=1, mode= "min"),
             # Doğrulama kaybı (val_loss) izlenir, 50 epok boyunca iyileşme olmazsa eğitim durdurulur, 
             #durdurma mesajı yazdırılır 
             #ve minimum val_loss aranır.
             ModelCheckpoint(filepath = 'mymodel.keras', monitor = 'val_loss', mode ='min',
                             # En iyi val_loss'a sahip model mymodel.h5 dosyasına kaydedilir, 
                             #tüm model (ağırlıklar ve mimari) kaydedilir 
                             #ve kaydetme mesajı yazdırılır.
                             save_best_only= True,
                             #Sadece en iyi doğrulama kaybına sahip olan modeli kaydeder.
                             #Bu, en iyi performansa sahip modelin saklanmasını sağlar.
                             save_weights_only = False,
                             #Modelin tüm yapısını (ağırlıklar ve mimari) kaydeder.
                             #Eğer True olsaydı sadece ağırlıklar kaydedilirdi.
                             verbose=1)] 
                            #Model kaydedildiğinde bir mesaj yazdırır.

# %% [markdown]
# ### Modelin Eğitilmesi

# %%
history = model.fit(train_generator,
                    epochs=100,
                    validation_data=test_generator,
                    callbacks=callbacks,
                    steps_per_epoch=2276//32,
                    validation_steps=251//32)
# Model Kaydetme (doğru format)
model.save('mymodel.keras')
# Out:
# Epoch 1/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 6:50 8s/step - acc: 0.1914 - loss: 1.8243 - precision: 0.1545 - recall: 0.0050
# Epoch 1: val_loss improved from inf to 1.72436, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 167s 2s/step - acc: 0.1999 - loss: 1.7933 - precision: 0.1612 - recall: 0.0028 - val_acc: 0.2346 - val_loss: 1.7244 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 6:57 8s/step - acc: 0.2324 - loss: 1.7200 - precision: 0.1053 - recall: 2.3821e-05
# Epoch 2: val_loss improved from 1.72436 to 1.64006, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 158s 2s/step - acc: 0.2335 - loss: 1.7138 - precision: 0.7606 - recall: 1.6741e-04 - val_acc: 0.2485 - val_loss: 1.6401 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 6:43 8s/step - acc: 0.2725 - loss: 1.6357 - precision: 0.6835 - recall: 0.0334
# Epoch 3: val_loss improved from 1.64006 to 1.51479, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 145s 2s/step - acc: 0.2955 - loss: 1.6042 - precision: 0.7222 - recall: 0.0503 - val_acc: 0.3419 - val_loss: 1.5148 - val_precision: 0.9487 - val_recall: 0.0736
# Epoch 4/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 6:17 7s/step - acc: 0.3441 - loss: 1.5176 - precision: 0.7763 - recall: 0.0897
# Epoch 4: val_loss improved from 1.51479 to 1.40759, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 144s 2s/step - acc: 0.3565 - loss: 1.4943 - precision: 0.7696 - recall: 0.1031 - val_acc: 0.3917 - val_loss: 1.4076 - val_precision: 0.7963 - val_recall: 0.1710
# Epoch 5/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 6:34 8s/step - acc: 0.3927 - loss: 1.4285 - precision: 0.7633 - recall: 0.1352
# Epoch 5: val_loss did not improve from 1.40759
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 152s 2s/step - acc: 0.3967 - loss: 1.4194 - precision: 0.7509 - recall: 0.1433 - val_acc: 0.4235 - val_loss: 1.4086 - val_precision: 0.8198 - val_recall: 0.1809
# Epoch 6/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 6:33 8s/step - acc: 0.4270 - loss: 1.3685 - precision: 0.7434 - recall: 0.1639
# Epoch 6: val_loss improved from 1.40759 to 1.34953, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - acc: 0.4278 - loss: 1.3620 - precision: 0.7327 - recall: 0.1654 - val_acc: 0.4314 - val_loss: 1.3495 - val_precision: 0.8136 - val_recall: 0.1909
# Epoch 7/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 4:23 5s/step - acc: 0.4562 - loss: 1.3331 - precision: 0.7346 - recall: 0.1957
# Epoch 7: val_loss did not improve from 1.34953
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 100s 1s/step - acc: 0.4554 - loss: 1.3330 - precision: 0.7283 - recall: 0.1962 - val_acc: 0.3996 - val_loss: 1.3766 - val_precision: 0.7361 - val_recall: 0.2107
# Epoch 8/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:46 4s/step - acc: 0.4828 - loss: 1.2907 - precision: 0.7413 - recall: 0.2302
# Epoch 8: val_loss improved from 1.34953 to 1.32554, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 87s 1s/step - acc: 0.4791 - loss: 1.2969 - precision: 0.7430 - recall: 0.2250 - val_acc: 0.4294 - val_loss: 1.3255 - val_precision: 0.7589 - val_recall: 0.2127
# Epoch 9/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 4:00 5s/step - acc: 0.4877 - loss: 1.2884 - precision: 0.7390 - recall: 0.2533
# Epoch 9: val_loss improved from 1.32554 to 1.28606, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - acc: 0.4895 - loss: 1.2779 - precision: 0.7443 - recall: 0.2586 - val_acc: 0.4732 - val_loss: 1.2861 - val_precision: 0.7532 - val_recall: 0.2306
# Epoch 10/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 4:00 5s/step - acc: 0.4927 - loss: 1.2627 - precision: 0.7189 - recall: 0.2625
# Epoch 10: val_loss did not improve from 1.28606
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - acc: 0.4911 - loss: 1.2697 - precision: 0.7156 - recall: 0.2669 - val_acc: 0.4592 - val_loss: 1.2871 - val_precision: 0.8045 - val_recall: 0.2127
# Epoch 11/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:32 4s/step - acc: 0.5041 - loss: 1.2618 - precision: 0.7243 - recall: 0.2469
# Epoch 11: val_loss improved from 1.28606 to 1.27441, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - acc: 0.5008 - loss: 1.2676 - precision: 0.7127 - recall: 0.2543 - val_acc: 0.4493 - val_loss: 1.2744 - val_precision: 0.6698 - val_recall: 0.2823
# Epoch 12/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:55 5s/step - acc: 0.4943 - loss: 1.2355 - precision: 0.6968 - recall: 0.2918
# Epoch 12: val_loss improved from 1.27441 to 1.26016, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - acc: 0.4920 - loss: 1.2474 - precision: 0.7065 - recall: 0.2757 - val_acc: 0.4791 - val_loss: 1.2602 - val_precision: 0.7778 - val_recall: 0.2783
# Epoch 13/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:46 4s/step - acc: 0.5009 - loss: 1.2163 - precision: 0.7674 - recall: 0.2678
# Epoch 13: val_loss did not improve from 1.26016
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 87s 1s/step - acc: 0.5039 - loss: 1.2161 - precision: 0.7605 - recall: 0.2734 - val_acc: 0.4672 - val_loss: 1.3003 - val_precision: 0.6954 - val_recall: 0.2724
# Epoch 14/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:33 4s/step - acc: 0.5157 - loss: 1.1974 - precision: 0.7407 - recall: 0.3021
# Epoch 14: val_loss improved from 1.26016 to 1.22510, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - acc: 0.5139 - loss: 1.2039 - precision: 0.7376 - recall: 0.3031 - val_acc: 0.4851 - val_loss: 1.2251 - val_precision: 0.8797 - val_recall: 0.2326
# Epoch 15/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:47 4s/step - acc: 0.5159 - loss: 1.2224 - precision: 0.7687 - recall: 0.2833
# Epoch 15: val_loss improved from 1.22510 to 1.21400, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - acc: 0.5228 - loss: 1.2044 - precision: 0.7500 - recall: 0.3017 - val_acc: 0.4990 - val_loss: 1.2140 - val_precision: 0.7041 - val_recall: 0.2744
# Epoch 16/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:46 4s/step - acc: 0.5370 - loss: 1.1637 - precision: 0.7714 - recall: 0.3371
# Epoch 16: val_loss did not improve from 1.21400
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 87s 1s/step - acc: 0.5381 - loss: 1.1660 - precision: 0.7636 - recall: 0.3376 - val_acc: 0.5030 - val_loss: 1.2420 - val_precision: 0.7320 - val_recall: 0.2823
# Epoch 17/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:24 4s/step - acc: 0.5593 - loss: 1.1365 - precision: 0.7450 - recall: 0.3549
# Epoch 17: val_loss improved from 1.21400 to 1.17291, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - acc: 0.5576 - loss: 1.1404 - precision: 0.7493 - recall: 0.3493 - val_acc: 0.5348 - val_loss: 1.1729 - val_precision: 0.7670 - val_recall: 0.3141
# Epoch 18/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:23 4s/step - acc: 0.5606 - loss: 1.1382 - precision: 0.7682 - recall: 0.3569
# Epoch 18: val_loss did not improve from 1.17291
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - acc: 0.5579 - loss: 1.1406 - precision: 0.7657 - recall: 0.3520 - val_acc: 0.5308 - val_loss: 1.1791 - val_precision: 0.7433 - val_recall: 0.2763
# Epoch 19/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:45 4s/step - acc: 0.4873 - loss: 1.2829 - precision: 0.7453 - recall: 0.2684
# Epoch 19: val_loss improved from 1.17291 to 1.16757, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - acc: 0.5124 - loss: 1.2327 - precision: 0.7513 - recall: 0.2978 - val_acc: 0.5308 - val_loss: 1.1676 - val_precision: 0.8119 - val_recall: 0.3260
# Epoch 20/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:32 4s/step - acc: 0.5751 - loss: 1.1041 - precision: 0.7559 - recall: 0.3727
# Epoch 20: val_loss improved from 1.16757 to 1.14764, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - acc: 0.5774 - loss: 1.1007 - precision: 0.7602 - recall: 0.3758 - val_acc: 0.5746 - val_loss: 1.1476 - val_precision: 0.8488 - val_recall: 0.3459
# Epoch 21/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:32 4s/step - acc: 0.5926 - loss: 1.0805 - precision: 0.7805 - recall: 0.3983
# Epoch 21: val_loss improved from 1.14764 to 1.12910, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - acc: 0.5923 - loss: 1.0859 - precision: 0.7717 - recall: 0.3926 - val_acc: 0.5586 - val_loss: 1.1291 - val_precision: 0.6992 - val_recall: 0.3698
# Epoch 22/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:29 4s/step - acc: 0.6010 - loss: 1.0564 - precision: 0.7703 - recall: 0.4200
# Epoch 22: val_loss did not improve from 1.12910
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - acc: 0.5908 - loss: 1.0716 - precision: 0.7689 - recall: 0.4074 - val_acc: 0.5308 - val_loss: 1.1650 - val_precision: 0.6880 - val_recall: 0.3419
# Epoch 23/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:26 4s/step - acc: 0.5945 - loss: 1.0686 - precision: 0.7583 - recall: 0.4193
# Epoch 23: val_loss improved from 1.12910 to 1.10503, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - acc: 0.5928 - loss: 1.0782 - precision: 0.7555 - recall: 0.4171 - val_acc: 0.6024 - val_loss: 1.1050 - val_precision: 0.8393 - val_recall: 0.3738
# Epoch 24/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 4:21 5s/step - acc: 0.6186 - loss: 1.0198 - precision: 0.7939 - recall: 0.4298
# Epoch 24: val_loss improved from 1.10503 to 1.08218, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 99s 1s/step - acc: 0.6243 - loss: 1.0128 - precision: 0.7951 - recall: 0.4464 - val_acc: 0.6024 - val_loss: 1.0822 - val_precision: 0.7815 - val_recall: 0.4195
# Epoch 25/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 4:05 5s/step - acc: 0.6317 - loss: 0.9966 - precision: 0.7714 - recall: 0.4621
# Epoch 25: val_loss improved from 1.08218 to 1.03082, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - acc: 0.6335 - loss: 0.9923 - precision: 0.7754 - recall: 0.4646 - val_acc: 0.6342 - val_loss: 1.0308 - val_precision: 0.7970 - val_recall: 0.4294
# Epoch 26/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 4:08 5s/step - acc: 0.6573 - loss: 0.9480 - precision: 0.7906 - recall: 0.4966
# Epoch 26: val_loss improved from 1.03082 to 1.02872, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - acc: 0.6503 - loss: 0.9632 - precision: 0.7873 - recall: 0.4873 - val_acc: 0.6183 - val_loss: 1.0287 - val_precision: 0.8103 - val_recall: 0.4672
# Epoch 27/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:39 4s/step - acc: 0.6504 - loss: 0.9507 - precision: 0.7992 - recall: 0.5079
# Epoch 27: val_loss did not improve from 1.02872
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - acc: 0.6498 - loss: 0.9468 - precision: 0.7924 - recall: 0.5100 - val_acc: 0.6143 - val_loss: 1.0981 - val_precision: 0.7875 - val_recall: 0.4493
# Epoch 28/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:33 4s/step - acc: 0.6589 - loss: 0.9584 - precision: 0.7975 - recall: 0.5011
# Epoch 28: val_loss improved from 1.02872 to 0.99769, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - acc: 0.6569 - loss: 0.9517 - precision: 0.7900 - recall: 0.5043 - val_acc: 0.6382 - val_loss: 0.9977 - val_precision: 0.8065 - val_recall: 0.4473
# Epoch 29/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:29 4s/step - acc: 0.6711 - loss: 0.9020 - precision: 0.8033 - recall: 0.5254
# Epoch 29: val_loss did not improve from 0.99769
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - acc: 0.6633 - loss: 0.9235 - precision: 0.7926 - recall: 0.5126 - val_acc: 0.6143 - val_loss: 1.0297 - val_precision: 0.8241 - val_recall: 0.4751
# Epoch 30/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:42 4s/step - acc: 0.6728 - loss: 0.8851 - precision: 0.8207 - recall: 0.5302
# Epoch 30: val_loss improved from 0.99769 to 0.97476, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 85s 1s/step - acc: 0.6738 - loss: 0.8798 - precision: 0.8179 - recall: 0.5332 - val_acc: 0.6223 - val_loss: 0.9748 - val_precision: 0.7919 - val_recall: 0.5070
# Epoch 31/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:36 4s/step - acc: 0.6808 - loss: 0.8544 - precision: 0.8178 - recall: 0.5589
# Epoch 31: val_loss did not improve from 0.97476
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - acc: 0.6790 - loss: 0.8663 - precision: 0.8135 - recall: 0.5515 - val_acc: 0.6342 - val_loss: 1.0007 - val_precision: 0.7594 - val_recall: 0.4831
# Epoch 32/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:29 4s/step - acc: 0.6762 - loss: 0.8818 - precision: 0.7998 - recall: 0.5424
# Epoch 32: val_loss did not improve from 0.97476
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - acc: 0.6808 - loss: 0.8694 - precision: 0.8053 - recall: 0.5452 - val_acc: 0.6302 - val_loss: 0.9960 - val_precision: 0.7835 - val_recall: 0.5109
# Epoch 33/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:36 4s/step - acc: 0.7021 - loss: 0.8278 - precision: 0.8207 - recall: 0.5823
# Epoch 33: val_loss improved from 0.97476 to 0.97052, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - acc: 0.6968 - loss: 0.8300 - precision: 0.8154 - recall: 0.5792 - val_acc: 0.6342 - val_loss: 0.9705 - val_precision: 0.7544 - val_recall: 0.5070
# Epoch 34/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:31 4s/step - acc: 0.6829 - loss: 0.8771 - precision: 0.7893 - recall: 0.5617
# Epoch 34: val_loss did not improve from 0.97052
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - acc: 0.6821 - loss: 0.8791 - precision: 0.7913 - recall: 0.5519 - val_acc: 0.6064 - val_loss: 1.0390 - val_precision: 0.7710 - val_recall: 0.4751
# Epoch 35/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:46 4s/step - acc: 0.6863 - loss: 0.8590 - precision: 0.8029 - recall: 0.5487
# Epoch 35: val_loss improved from 0.97052 to 0.96907, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - acc: 0.6867 - loss: 0.8578 - precision: 0.8074 - recall: 0.5520 - val_acc: 0.6382 - val_loss: 0.9691 - val_precision: 0.8164 - val_recall: 0.4950
# Epoch 36/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:37 4s/step - acc: 0.7119 - loss: 0.8014 - precision: 0.8259 - recall: 0.5885
# Epoch 36: val_loss improved from 0.96907 to 0.93258, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - acc: 0.7062 - loss: 0.8228 - precision: 0.8194 - recall: 0.5765 - val_acc: 0.6421 - val_loss: 0.9326 - val_precision: 0.8019 - val_recall: 0.5070
# Epoch 37/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:37 4s/step - acc: 0.7002 - loss: 0.8127 - precision: 0.8207 - recall: 0.5694
# Epoch 37: val_loss did not improve from 0.93258
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - acc: 0.6959 - loss: 0.8259 - precision: 0.8116 - recall: 0.5678 - val_acc: 0.6421 - val_loss: 0.9598 - val_precision: 0.7550 - val_recall: 0.5268
# Epoch 38/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:41 4s/step - acc: 0.7102 - loss: 0.8037 - precision: 0.8224 - recall: 0.5987
# Epoch 38: val_loss did not improve from 0.93258
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 85s 1s/step - acc: 0.7075 - loss: 0.8110 - precision: 0.8173 - recall: 0.5942 - val_acc: 0.6382 - val_loss: 0.9351 - val_precision: 0.7840 - val_recall: 0.5268
# Epoch 39/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:45 4s/step - acc: 0.7208 - loss: 0.8142 - precision: 0.8125 - recall: 0.5862
# Epoch 39: val_loss did not improve from 0.93258
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 86s 1s/step - acc: 0.7134 - loss: 0.8196 - precision: 0.8165 - recall: 0.5802 - val_acc: 0.6402 - val_loss: 0.9757 - val_precision: 0.7751 - val_recall: 0.5209
# Epoch 40/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:31 4s/step - acc: 0.7070 - loss: 0.7882 - precision: 0.8273 - recall: 0.6006
# Epoch 40: val_loss improved from 0.93258 to 0.91638, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - acc: 0.7055 - loss: 0.7968 - precision: 0.8248 - recall: 0.5938 - val_acc: 0.6740 - val_loss: 0.9164 - val_precision: 0.8138 - val_recall: 0.5388
# Epoch 41/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:44 4s/step - acc: 0.7081 - loss: 0.7677 - precision: 0.8203 - recall: 0.6071
# Epoch 41: val_loss improved from 0.91638 to 0.89283, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 86s 1s/step - acc: 0.7156 - loss: 0.7594 - precision: 0.8211 - recall: 0.6113 - val_acc: 0.6620 - val_loss: 0.8928 - val_precision: 0.7796 - val_recall: 0.5626
# Epoch 42/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:46 4s/step - acc: 0.7273 - loss: 0.7630 - precision: 0.8238 - recall: 0.6175
# Epoch 42: val_loss did not improve from 0.89283
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 86s 1s/step - acc: 0.7256 - loss: 0.7589 - precision: 0.8231 - recall: 0.6178 - val_acc: 0.6501 - val_loss: 0.9241 - val_precision: 0.8090 - val_recall: 0.5388
# Epoch 43/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:38 4s/step - acc: 0.7247 - loss: 0.7584 - precision: 0.8260 - recall: 0.6170
# Epoch 43: val_loss improved from 0.89283 to 0.88872, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 85s 1s/step - acc: 0.7207 - loss: 0.7618 - precision: 0.8191 - recall: 0.6183 - val_acc: 0.6660 - val_loss: 0.8887 - val_precision: 0.8349 - val_recall: 0.5427
# Epoch 44/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:38 4s/step - acc: 0.7246 - loss: 0.7873 - precision: 0.8249 - recall: 0.5971
# Epoch 44: val_loss did not improve from 0.88872
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - acc: 0.7284 - loss: 0.7691 - precision: 0.8269 - recall: 0.6052 - val_acc: 0.6799 - val_loss: 0.9315 - val_precision: 0.7669 - val_recall: 0.5626
# Epoch 45/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:58 5s/step - acc: 0.7154 - loss: 0.7648 - precision: 0.8107 - recall: 0.6243
# Epoch 45: val_loss did not improve from 0.88872
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 86s 1s/step - acc: 0.7180 - loss: 0.7619 - precision: 0.8172 - recall: 0.6164 - val_acc: 0.6521 - val_loss: 0.9061 - val_precision: 0.7950 - val_recall: 0.5706
# Epoch 46/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:39 4s/step - acc: 0.7299 - loss: 0.7508 - precision: 0.8262 - recall: 0.6169
# Epoch 46: val_loss improved from 0.88872 to 0.84092, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - acc: 0.7375 - loss: 0.7309 - precision: 0.8324 - recall: 0.6268 - val_acc: 0.6759 - val_loss: 0.8409 - val_precision: 0.7844 - val_recall: 0.5785
# Epoch 47/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 4:19 5s/step - acc: 0.7489 - loss: 0.6660 - precision: 0.8342 - recall: 0.6675
# Epoch 47: val_loss did not improve from 0.84092
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 99s 1s/step - acc: 0.7447 - loss: 0.6823 - precision: 0.8310 - recall: 0.6585 - val_acc: 0.6899 - val_loss: 0.9084 - val_precision: 0.7947 - val_recall: 0.6004
# Epoch 48/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:35 4s/step - acc: 0.7264 - loss: 0.7466 - precision: 0.8262 - recall: 0.6190
# Epoch 48: val_loss did not improve from 0.84092
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - acc: 0.7384 - loss: 0.7257 - precision: 0.8284 - recall: 0.6307 - val_acc: 0.6700 - val_loss: 0.9212 - val_precision: 0.7533 - val_recall: 0.5706
# Epoch 49/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:25:54 238s/step - acc: 0.7469 - loss: 0.6968 - precision: 0.8357 - recall: 0.6422
# Epoch 49: val_loss did not improve from 0.84092
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4285s 61s/step - acc: 0.7530 - loss: 0.6896 - precision: 0.8399 - recall: 0.6548 - val_acc: 0.6501 - val_loss: 0.9417 - val_precision: 0.7546 - val_recall: 0.5746
# Epoch 50/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 4:27 5s/step - acc: 0.7447 - loss: 0.7168 - precision: 0.8343 - recall: 0.6443
# Epoch 50: val_loss did not improve from 0.84092
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 102s 1s/step - acc: 0.7394 - loss: 0.7154 - precision: 0.8315 - recall: 0.6444 - val_acc: 0.6620 - val_loss: 0.8980 - val_precision: 0.7984 - val_recall: 0.5825
# Epoch 51/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 4:02 5s/step - acc: 0.7477 - loss: 0.7057 - precision: 0.8318 - recall: 0.6514
# Epoch 51: val_loss did not improve from 0.84092
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 93s 1s/step - acc: 0.7500 - loss: 0.6895 - precision: 0.8372 - recall: 0.6566 - val_acc: 0.6779 - val_loss: 0.8587 - val_precision: 0.7825 - val_recall: 0.5865
# Epoch 52/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 4:02 5s/step - acc: 0.7724 - loss: 0.6436 - precision: 0.8499 - recall: 0.6837
# Epoch 52: val_loss did not improve from 0.84092
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 93s 1s/step - acc: 0.7727 - loss: 0.6482 - precision: 0.8521 - recall: 0.6856 - val_acc: 0.6581 - val_loss: 0.8419 - val_precision: 0.8203 - val_recall: 0.5626
# Epoch 53/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:56 5s/step - acc: 0.7608 - loss: 0.6629 - precision: 0.8540 - recall: 0.6711
# Epoch 53: val_loss did not improve from 0.84092
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - acc: 0.7627 - loss: 0.6597 - precision: 0.8509 - recall: 0.6741 - val_acc: 0.6541 - val_loss: 0.8856 - val_precision: 0.7743 - val_recall: 0.5865
# Epoch 54/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 4:10 5s/step - acc: 0.7588 - loss: 0.6564 - precision: 0.8406 - recall: 0.6781
# Epoch 54: val_loss did not improve from 0.84092
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - acc: 0.7564 - loss: 0.6624 - precision: 0.8382 - recall: 0.6744 - val_acc: 0.6740 - val_loss: 0.9421 - val_precision: 0.7759 - val_recall: 0.6262
# Epoch 55/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 4:12 5s/step - acc: 0.7497 - loss: 0.6924 - precision: 0.8288 - recall: 0.6665
# Epoch 55: val_loss did not improve from 0.84092
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 97s 1s/step - acc: 0.7506 - loss: 0.6840 - precision: 0.8316 - recall: 0.6669 - val_acc: 0.6620 - val_loss: 0.9182 - val_precision: 0.7340 - val_recall: 0.5706
# Epoch 56/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 4:26 5s/step - acc: 0.7687 - loss: 0.6428 - precision: 0.8495 - recall: 0.6814
# Epoch 56: val_loss did not improve from 0.84092
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - acc: 0.7685 - loss: 0.6506 - precision: 0.8494 - recall: 0.6809 - val_acc: 0.6700 - val_loss: 0.8753 - val_precision: 0.7603 - val_recall: 0.5865
# Epoch 57/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 4:07 5s/step - acc: 0.7601 - loss: 0.6348 - precision: 0.8468 - recall: 0.6816
# Epoch 57: val_loss improved from 0.84092 to 0.81813, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - acc: 0.7607 - loss: 0.6370 - precision: 0.8453 - recall: 0.6818 - val_acc: 0.6581 - val_loss: 0.8181 - val_precision: 0.7951 - val_recall: 0.5785
# Epoch 58/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 4:10 5s/step - acc: 0.7639 - loss: 0.6330 - precision: 0.8422 - recall: 0.6865
# Epoch 58: val_loss did not improve from 0.81813
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - acc: 0.7611 - loss: 0.6420 - precision: 0.8409 - recall: 0.6824 - val_acc: 0.5944 - val_loss: 1.0798 - val_precision: 0.7022 - val_recall: 0.5109
# Epoch 59/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 4:16 5s/step - acc: 0.7445 - loss: 0.6997 - precision: 0.8284 - recall: 0.6545
# Epoch 59: val_loss did not improve from 0.81813
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 98s 1s/step - acc: 0.7527 - loss: 0.6759 - precision: 0.8343 - recall: 0.6637 - val_acc: 0.6541 - val_loss: 0.8987 - val_precision: 0.7598 - val_recall: 0.5785
# Epoch 60/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 4:10 5s/step - acc: 0.7740 - loss: 0.6445 - precision: 0.8497 - recall: 0.7022
# Epoch 60: val_loss did not improve from 0.81813
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - acc: 0.7700 - loss: 0.6381 - precision: 0.8498 - recall: 0.6965 - val_acc: 0.6779 - val_loss: 0.8392 - val_precision: 0.7909 - val_recall: 0.5865
# Epoch 61/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 4:16 5s/step - acc: 0.7762 - loss: 0.6279 - precision: 0.8416 - recall: 0.6962
# Epoch 61: val_loss did not improve from 0.81813
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 98s 1s/step - acc: 0.7725 - loss: 0.6385 - precision: 0.8422 - recall: 0.6857 - val_acc: 0.6799 - val_loss: 0.8349 - val_precision: 0.7962 - val_recall: 0.5825
# Epoch 62/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 4:13 5s/step - acc: 0.7762 - loss: 0.6110 - precision: 0.8428 - recall: 0.6938
# Epoch 62: val_loss improved from 0.81813 to 0.80209, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 97s 1s/step - acc: 0.7722 - loss: 0.6168 - precision: 0.8440 - recall: 0.6944 - val_acc: 0.6938 - val_loss: 0.8021 - val_precision: 0.7963 - val_recall: 0.6064
# Epoch 63/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 4:10 5s/step - acc: 0.7790 - loss: 0.5883 - precision: 0.8511 - recall: 0.7122
# Epoch 63: val_loss did not improve from 0.80209
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - acc: 0.7758 - loss: 0.5947 - precision: 0.8475 - recall: 0.7080 - val_acc: 0.6680 - val_loss: 0.8275 - val_precision: 0.7721 - val_recall: 0.6262
# Epoch 64/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 4:09 5s/step - acc: 0.7902 - loss: 0.5952 - precision: 0.8520 - recall: 0.7213
# Epoch 64: val_loss did not improve from 0.80209
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - acc: 0.7827 - loss: 0.6114 - precision: 0.8477 - recall: 0.7137 - val_acc: 0.6640 - val_loss: 0.8667 - val_precision: 0.7930 - val_recall: 0.5865
# Epoch 65/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 4:12 5s/step - acc: 0.7847 - loss: 0.5982 - precision: 0.8588 - recall: 0.7041
# Epoch 65: val_loss did not improve from 0.80209
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 97s 1s/step - acc: 0.7839 - loss: 0.5996 - precision: 0.8546 - recall: 0.7062 - val_acc: 0.6859 - val_loss: 0.8101 - val_precision: 0.7786 - val_recall: 0.5944
# Epoch 66/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 4:25 5s/step - acc: 0.7725 - loss: 0.6019 - precision: 0.8480 - recall: 0.6878
# Epoch 66: val_loss did not improve from 0.80209
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - acc: 0.7749 - loss: 0.6084 - precision: 0.8507 - recall: 0.6947 - val_acc: 0.6819 - val_loss: 0.8119 - val_precision: 0.8026 - val_recall: 0.6143
# Epoch 67/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 4:17 5s/step - acc: 0.7765 - loss: 0.6204 - precision: 0.8453 - recall: 0.6910
# Epoch 67: val_loss improved from 0.80209 to 0.77850, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 100s 1s/step - acc: 0.7767 - loss: 0.6138 - precision: 0.8452 - recall: 0.6956 - val_acc: 0.6978 - val_loss: 0.7785 - val_precision: 0.7714 - val_recall: 0.6103
# Epoch 68/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 4:05 5s/step - acc: 0.7987 - loss: 0.5484 - precision: 0.8656 - recall: 0.7262
# Epoch 68: val_loss did not improve from 0.77850
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - acc: 0.7935 - loss: 0.5565 - precision: 0.8616 - recall: 0.7229 - val_acc: 0.6938 - val_loss: 0.8457 - val_precision: 0.7601 - val_recall: 0.5984
# Epoch 69/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:28 4s/step - acc: 0.7857 - loss: 0.5661 - precision: 0.8602 - recall: 0.7195
# Epoch 69: val_loss did not improve from 0.77850
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - acc: 0.7815 - loss: 0.5805 - precision: 0.8555 - recall: 0.7162 - val_acc: 0.6879 - val_loss: 0.8993 - val_precision: 0.7664 - val_recall: 0.6262
# Epoch 70/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:56 5s/step - acc: 0.7969 - loss: 0.5816 - precision: 0.8605 - recall: 0.7245
# Epoch 70: val_loss did not improve from 0.77850
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - acc: 0.7972 - loss: 0.5818 - precision: 0.8620 - recall: 0.7235 - val_acc: 0.6680 - val_loss: 0.8562 - val_precision: 0.7809 - val_recall: 0.6024
# Epoch 71/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:53 4s/step - acc: 0.8036 - loss: 0.5621 - precision: 0.8652 - recall: 0.7344
# Epoch 71: val_loss did not improve from 0.77850
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - acc: 0.8044 - loss: 0.5638 - precision: 0.8667 - recall: 0.7320 - val_acc: 0.6899 - val_loss: 0.8231 - val_precision: 0.7702 - val_recall: 0.6064
# Epoch 72/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:51 4s/step - acc: 0.8011 - loss: 0.5648 - precision: 0.8657 - recall: 0.7373
# Epoch 72: val_loss did not improve from 0.77850
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - acc: 0.7996 - loss: 0.5764 - precision: 0.8634 - recall: 0.7281 - val_acc: 0.7217 - val_loss: 0.8085 - val_precision: 0.8182 - val_recall: 0.6083
# Epoch 73/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:53 4s/step - acc: 0.7823 - loss: 0.5757 - precision: 0.8587 - recall: 0.7162
# Epoch 73: val_loss did not improve from 0.77850
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - acc: 0.7844 - loss: 0.5729 - precision: 0.8546 - recall: 0.7198 - val_acc: 0.7097 - val_loss: 0.8227 - val_precision: 0.8064 - val_recall: 0.6541
# Epoch 74/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:52 4s/step - acc: 0.8091 - loss: 0.5170 - precision: 0.8630 - recall: 0.7503
# Epoch 74: val_loss improved from 0.77850 to 0.77105, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - acc: 0.8046 - loss: 0.5318 - precision: 0.8582 - recall: 0.7456 - val_acc: 0.6958 - val_loss: 0.7711 - val_precision: 0.8232 - val_recall: 0.6481
# Epoch 75/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:55 5s/step - acc: 0.8096 - loss: 0.5186 - precision: 0.8735 - recall: 0.7482
# Epoch 75: val_loss did not improve from 0.77105
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - acc: 0.8065 - loss: 0.5246 - precision: 0.8682 - recall: 0.7481 - val_acc: 0.6978 - val_loss: 0.8316 - val_precision: 0.8130 - val_recall: 0.6223
# Epoch 76/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:57 5s/step - acc: 0.7893 - loss: 0.5769 - precision: 0.8561 - recall: 0.7310
# Epoch 76: val_loss did not improve from 0.77105
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - acc: 0.7911 - loss: 0.5745 - precision: 0.8567 - recall: 0.7298 - val_acc: 0.6998 - val_loss: 0.9176 - val_precision: 0.7772 - val_recall: 0.6103
# Epoch 77/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:54 5s/step - acc: 0.7994 - loss: 0.5759 - precision: 0.8703 - recall: 0.7325
# Epoch 77: val_loss did not improve from 0.77105
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - acc: 0.7880 - loss: 0.5986 - precision: 0.8604 - recall: 0.7199 - val_acc: 0.7197 - val_loss: 0.8060 - val_precision: 0.7877 - val_recall: 0.6123
# Epoch 78/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:55 5s/step - acc: 0.7996 - loss: 0.5312 - precision: 0.8606 - recall: 0.7368
# Epoch 78: val_loss improved from 0.77105 to 0.76984, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - acc: 0.7998 - loss: 0.5344 - precision: 0.8611 - recall: 0.7384 - val_acc: 0.7078 - val_loss: 0.7698 - val_precision: 0.7941 - val_recall: 0.6441
# Epoch 79/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:56 5s/step - acc: 0.8099 - loss: 0.5482 - precision: 0.8673 - recall: 0.7412
# Epoch 79: val_loss did not improve from 0.76984
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - acc: 0.8023 - loss: 0.5641 - precision: 0.8569 - recall: 0.7335 - val_acc: 0.7256 - val_loss: 0.8133 - val_precision: 0.8145 - val_recall: 0.6461
# Epoch 80/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:31 4s/step - acc: 0.8060 - loss: 0.5317 - precision: 0.8706 - recall: 0.7529
# Epoch 80: val_loss did not improve from 0.76984
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - acc: 0.8038 - loss: 0.5370 - precision: 0.8660 - recall: 0.7495 - val_acc: 0.7018 - val_loss: 0.7779 - val_precision: 0.7797 - val_recall: 0.6262
# Epoch 81/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:53 4s/step - acc: 0.8026 - loss: 0.5592 - precision: 0.8620 - recall: 0.7417
# Epoch 81: val_loss did not improve from 0.76984
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - acc: 0.8052 - loss: 0.5485 - precision: 0.8663 - recall: 0.7409 - val_acc: 0.7177 - val_loss: 0.8359 - val_precision: 0.7918 - val_recall: 0.6501
# Epoch 82/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 4:00 5s/step - acc: 0.7943 - loss: 0.5691 - precision: 0.8528 - recall: 0.7265
# Epoch 82: val_loss did not improve from 0.76984
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - acc: 0.8028 - loss: 0.5543 - precision: 0.8624 - recall: 0.7360 - val_acc: 0.7078 - val_loss: 0.7992 - val_precision: 0.7723 - val_recall: 0.6541
# Epoch 83/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:25 4s/step - acc: 0.8120 - loss: 0.5224 - precision: 0.8712 - recall: 0.7569
# Epoch 83: val_loss did not improve from 0.76984
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - acc: 0.8086 - loss: 0.5283 - precision: 0.8715 - recall: 0.7533 - val_acc: 0.6978 - val_loss: 0.8503 - val_precision: 0.7879 - val_recall: 0.6203
# Epoch 84/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:23 4s/step - acc: 0.8176 - loss: 0.4968 - precision: 0.8841 - recall: 0.7658
# Epoch 84: val_loss did not improve from 0.76984
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - acc: 0.8212 - loss: 0.4859 - precision: 0.8809 - recall: 0.7692 - val_acc: 0.7097 - val_loss: 0.7777 - val_precision: 0.7810 - val_recall: 0.6521
# Epoch 85/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:21 4s/step - acc: 0.8126 - loss: 0.5192 - precision: 0.8706 - recall: 0.7571
# Epoch 85: val_loss did not improve from 0.76984
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - acc: 0.8131 - loss: 0.5195 - precision: 0.8722 - recall: 0.7561 - val_acc: 0.7157 - val_loss: 0.7839 - val_precision: 0.8107 - val_recall: 0.6640
# Epoch 86/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:17 4s/step - acc: 0.8177 - loss: 0.5021 - precision: 0.8841 - recall: 0.7630
# Epoch 86: val_loss improved from 0.76984 to 0.76891, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - acc: 0.8121 - loss: 0.5146 - precision: 0.8791 - recall: 0.7553 - val_acc: 0.7157 - val_loss: 0.7689 - val_precision: 0.7884 - val_recall: 0.6223
# Epoch 87/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:21 4s/step - acc: 0.8141 - loss: 0.5123 - precision: 0.8685 - recall: 0.7489
# Epoch 87: val_loss improved from 0.76891 to 0.74499, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - acc: 0.8176 - loss: 0.5016 - precision: 0.8722 - recall: 0.7566 - val_acc: 0.7396 - val_loss: 0.7450 - val_precision: 0.8254 - val_recall: 0.6859
# Epoch 88/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:26 4s/step - acc: 0.8253 - loss: 0.4601 - precision: 0.8740 - recall: 0.7738
# Epoch 88: val_loss did not improve from 0.74499
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - acc: 0.8218 - loss: 0.4811 - precision: 0.8718 - recall: 0.7678 - val_acc: 0.7237 - val_loss: 0.7923 - val_precision: 0.8034 - val_recall: 0.6501
# Epoch 89/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:19 4s/step - acc: 0.8281 - loss: 0.4850 - precision: 0.8841 - recall: 0.7689
# Epoch 89: val_loss did not improve from 0.74499
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - acc: 0.8298 - loss: 0.4787 - precision: 0.8811 - recall: 0.7750 - val_acc: 0.7078 - val_loss: 0.7567 - val_precision: 0.8109 - val_recall: 0.6481
# Epoch 90/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:22 4s/step - acc: 0.8462 - loss: 0.4418 - precision: 0.8942 - recall: 0.7956
# Epoch 90: val_loss did not improve from 0.74499
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - acc: 0.8381 - loss: 0.4624 - precision: 0.8880 - recall: 0.7907 - val_acc: 0.7435 - val_loss: 0.8048 - val_precision: 0.8082 - val_recall: 0.7038
# Epoch 91/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:21 4s/step - acc: 0.8377 - loss: 0.4504 - precision: 0.8859 - recall: 0.7883
# Epoch 91: val_loss did not improve from 0.74499
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - acc: 0.8359 - loss: 0.4681 - precision: 0.8804 - recall: 0.7844 - val_acc: 0.7376 - val_loss: 0.7573 - val_precision: 0.8047 - val_recall: 0.6879
# Epoch 92/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:18 4s/step - acc: 0.8342 - loss: 0.4645 - precision: 0.8853 - recall: 0.7840
# Epoch 92: val_loss did not improve from 0.74499
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - acc: 0.8331 - loss: 0.4651 - precision: 0.8841 - recall: 0.7834 - val_acc: 0.7157 - val_loss: 0.7746 - val_precision: 0.8184 - val_recall: 0.6720
# Epoch 93/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:16 4s/step - acc: 0.8239 - loss: 0.4749 - precision: 0.8764 - recall: 0.7666
# Epoch 93: val_loss did not improve from 0.74499
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - acc: 0.8247 - loss: 0.4793 - precision: 0.8788 - recall: 0.7694 - val_acc: 0.7097 - val_loss: 0.8089 - val_precision: 0.7788 - val_recall: 0.6581
# Epoch 94/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:18 4s/step - acc: 0.8464 - loss: 0.4414 - precision: 0.8888 - recall: 0.7933
# Epoch 94: val_loss did not improve from 0.74499
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - acc: 0.8333 - loss: 0.4647 - precision: 0.8815 - recall: 0.7809 - val_acc: 0.7276 - val_loss: 0.8190 - val_precision: 0.8127 - val_recall: 0.6640
# Epoch 95/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:19 4s/step - acc: 0.8415 - loss: 0.4430 - precision: 0.8841 - recall: 0.7912
# Epoch 95: val_loss did not improve from 0.74499
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - acc: 0.8384 - loss: 0.4479 - precision: 0.8842 - recall: 0.7887 - val_acc: 0.7435 - val_loss: 0.7511 - val_precision: 0.8349 - val_recall: 0.7038
# Epoch 96/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:19 4s/step - acc: 0.8576 - loss: 0.4058 - precision: 0.9024 - recall: 0.8146
# Epoch 96: val_loss did not improve from 0.74499
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - acc: 0.8472 - loss: 0.4247 - precision: 0.8951 - recall: 0.8035 - val_acc: 0.7276 - val_loss: 0.7716 - val_precision: 0.8160 - val_recall: 0.6879
# Epoch 97/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:16 4s/step - acc: 0.8341 - loss: 0.4616 - precision: 0.8778 - recall: 0.7891
# Epoch 97: val_loss did not improve from 0.74499
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - acc: 0.8269 - loss: 0.4743 - precision: 0.8738 - recall: 0.7859 - val_acc: 0.7197 - val_loss: 0.8417 - val_precision: 0.7903 - val_recall: 0.6819
# Epoch 98/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:16 4s/step - acc: 0.8099 - loss: 0.5303 - precision: 0.8674 - recall: 0.7508
# Epoch 98: val_loss improved from 0.74499 to 0.74396, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - acc: 0.8095 - loss: 0.5305 - precision: 0.8684 - recall: 0.7454 - val_acc: 0.7535 - val_loss: 0.7440 - val_precision: 0.8225 - val_recall: 0.6819
# Epoch 99/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:17 4s/step - acc: 0.8317 - loss: 0.4700 - precision: 0.8845 - recall: 0.7844
# Epoch 99: val_loss did not improve from 0.74396
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - acc: 0.8387 - loss: 0.4518 - precision: 0.8888 - recall: 0.7909 - val_acc: 0.6978 - val_loss: 0.8316 - val_precision: 0.7767 - val_recall: 0.6501
# Epoch 100/100
# 19/71 ━━━━━━━━━━━━━━━━━━━━ 3:18 4s/step - acc: 0.8287 - loss: 0.4501 - precision: 0.8879 - recall: 0.7902
# Epoch 100: val_loss improved from 0.74396 to 0.69423, saving model to mymodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - acc: 0.8345 - loss: 0.4436 - precision: 0.8895 - recall: 0.7967 - val_acc: 0.7714 - val_loss: 0.6942 - val_precision: 0.8333 - val_recall: 0.7356

# %% [markdown]
# ### Accuracy ve Loss grafikleri

# %%
import os

dir_path = r"C:\Users\glylm\Desktop\dp\Solid_waste_detection_with_CNN\Garbage_classification\Garbageclassification"
for folder in os.listdir(dir_path):
    class_dir = os.path.join(dir_path, folder)
    for fname in os.listdir(class_dir):
        fpath = os.path.join(class_dir, fname)
        if not os.path.isfile(fpath):
            print(f"Missing: {fpath}")

# %%
# ACCURACY GRAFİĞİ
plt.figure(figsize= (20,5))
plt.subplot(1,2,1)
plt.plot(history.history['acc'], label = 'Traning Accuracy')
plt.plot(history.history['val_acc'],label='Validation Accuracy')
plt.legend(loc = 'lower right')
plt.xlabel('Epoch', fontsize=16)
plt.ylabel('Accuracy' ,fontsize= 16)
plt.ylim(min(plt.ylim()),1)
plt.title('Traning and Validation Accuracy', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Traning and Validation Accuracy')

# %%
# LOSS GRAFİĞİ
plt.figure(figsize= (20,5))
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label = 'Traning Loss')
plt.plot(history.history['val_loss'],label='Validation Loss')
plt.legend(loc = 'upper right')
plt.xlabel('Epoch', fontsize=16)
plt.ylabel('Loss' ,fontsize= 16)
plt.ylim([0,max(plt.ylim())])
plt.title('Traning and Validation Loss', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Traning and Validation Loss')

# %% [markdown]
# ### Değerlendirme(Evaluation)

# %%
loss, precision,recall,acc = model.evaluate(test_generator, batch_size= 32)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 457ms/step - acc: 0.7647 - loss: 0.7035 - precision: 0.8300 - recall: 0.7288

# %%
print("\nTest accuracy: %.lf%%" %(100.0 * acc))
print("\nTest loss: %.lf%%" %(100.0 * loss))
print("\nTest precision: %.lf%%" %(100.0 * precision))
print("\nTest recall: %.lf%%" %(100.0 * recall))
# Out:
# Test accuracy: 77%
#
# Test loss: 69%
#
# Test precision: 83%
#
# Test recall: 74%

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Sınıf isimlerini al
class_names = list(test_generator.class_indices.keys())

# Tüm test verisini topla
x_test, y_test = [], []
for i in range(len(test_generator)):
    x, y = test_generator[i]
    x_test.extend(x)
    y_test.extend(y)

x_test = np.array(x_test)
y_test = np.array(y_test)

# Tahmin
y_pred = model.predict(x_test)
y_pred = np.argmax(y_pred, axis=1)
y_test = np.argmax(y_test, axis=1)

# Classification report
print(classification_report(y_test, y_pred, target_names=class_names))

# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step
#               precision    recall  f1-score   support
#
#    cardboard       0.88      0.72      0.79        80
#        glass       0.83      0.90      0.87       100
#        metal       0.77      0.73      0.75        82
#        paper       0.77      0.93      0.84       118
#      plastic       0.70      0.54      0.61        96
#        trash       0.53      0.67      0.59        27
#
#     accuracy                           0.77       503
#    macro avg       0.75      0.75      0.74       503
# weighted avg       0.77      0.77      0.77       503

# %%
target_names = list(waste_labels.keys())

# %%
print(classification_report(y_test, y_pred,target_names = target_names))
# Out:
#               precision    recall  f1-score   support
#
#    cardboard       0.88      0.72      0.79        80
#        glass       0.83      0.90      0.87       100
#        metal       0.77      0.73      0.75        82
#        paper       0.77      0.93      0.84       118
#      plastic       0.70      0.54      0.61        96
#        trash       0.53      0.67      0.59        27
#
#     accuracy                           0.77       503
#    macro avg       0.75      0.75      0.74       503
# weighted avg       0.77      0.77      0.77       503

# %% [markdown]
# ### Modelin Kullanılması/Test edilmesi

# %%
waste_labels = {0: 'cardboard', 1: 'glasses', 2:'metal', 3: 'paper',4: 'plastic', 5:'trash'}

# %%
def model_testing(path):
    '''
    Görsellerin bulunduğu dizindeki görüntüyü okuyup model aracılıgı ile hangi sınıfa ait olduguna 
    dair tahmin işlemi gerceklestirilir.
    Parametreler:
    path: Görsellerin bulunduğu dizini ifade eder.
    Return:
    img: Görüntü
    p: Tahmin olasılıkları
    predicted_class: Tahmin sınıfı
    '''
    img = image.load_img(path,target_size = (target_size))
    img=image.img_to_array(img, dtype= np.uint8)
    img =np.array(img)/255.0
    p=model.predict(img.reshape(1,224,224,3))
    predicted_class = np.argmax(p[0])
    
    return img,p, predicted_class


img1,p1, predicted_classes1 = model_testing(r'C:\Users\glylm\Desktop\dp\Solid_waste_detection_with_CNN\deney1.jpg')
img2,p2, predicted_classes2 = model_testing(r'C:\Users\glylm\Desktop\dp\Solid_waste_detection_with_CNN\deney2.jpg')
img3,p3, predicted_classes3 = model_testing(r'C:\Users\glylm\Desktop\dp\Solid_waste_detection_with_CNN\deney1.jpg')
img4,p4, predicted_classes4 = model_testing(r'C:\Users\glylm\Desktop\dp\Solid_waste_detection_with_CNN\deney2.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step

# %%
plt.figure(figsize=(20,60))

plt.subplot(141)
plt.axis('off')
plt.imshow(img1.squeeze())
plt.title("Maximum Probability: " + str(np.max(p1[0], axis= -1)) + "/n" + "Predicted classes1:" + str(waste_labels[predicted_classes1]))
plt.imshow(img1);

# %%
plt.subplot(142)
plt.axis('off')
plt.imshow(img2.squeeze())
plt.title("Maximum Probability: " + str(np.max(p2[0], axis= -1)) + "/n" + "Predicted classes2:" + str(waste_labels[predicted_classes2]))
plt.imshow(img2);
